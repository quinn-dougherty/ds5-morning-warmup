# %%
from numpy.random import choice
from typing import List
import pandas as pd

x = ['Louis Agassiz', 'Maria Gaetana Agnesi', 'Al-Battani', 'Abu Nasr Al-Farabi',
        'Alhazen', 'Jim Al-Khalili',
        'Muhammad ibn Musa al-Khwarizmi',
        'Mihailo Petrovic Alas',
        'Angel Alcala', 'Salim Ali', 'Luis Alvarez',
        'Andre Marie Ampère', 'Anaximander',
        'Carl Anderson', 'Mary Anning',
        'Virginia Apgar', 'Archimedes',
        'Agnes Arber', 'Aristarchus',
        'Aristotle', 'Svante Arrhenius',
        'Oswald Avery', 'Amedeo Avogadro', 'Avicenna', 'Blaise Pascal' 'Louis Pasteur',
        'Wolfgang Ernst Pauli',
        'Linus Pauling',
        'Randy Pausch',
        'Ivan Pavlov',
        'Cecilia Payne-Gaposchkin',
        'Wilder Penfield',
        'Marguerite Perey',
        'William Perkin',
        'John Philoponus',
        'Jean Piaget',
        'Philippe Pinel',
        'Max Planck',
        'Pliny the Elder',
        'Karl Popper',
        'Beatrix Potter',
        'Joseph Priestley',
        'Proclus',
        'Claudius Ptolemy',
        'Pythagoras', 'Niccolo Tartaglia',
        'Edward Teller',
        'Nikola Tesla',
        'Thales of Miletus',
        'Theon of Alexandria',
        'Benjamin Thompson',
        'J. J. Thomson',
        'William Thomson',
        'Henry David Thoreau',
        'Kip S. Thorne',
        'Clyde Tombaugh',
        'Susumu Tonegawa',
        'Evangelista Torricelli',
        'Charles Townes',
        'Youyou Tu',
        'Alan Turing',
        'Neil deGrasse Tyson']

def set_names(dat: pd.DataFrame, names: List[str] = x) -> pd.DataFrame: 
    return dat.rename(index={k: choice(names) for k in range(dat.shape[0])})

set_names(pd.read_csv('survey_.csv', sep='\t')).to_csv('survey.csv', index_label='Unnamed: 0')

# %%
pd.read_csv('survey.csv')
# Out:
#                 Unnamed: 0  What is your programming level?  \
# 0   Evangelista Torricelli                              6.0
# 1               Pythagoras                              1.0
# 2                  Alhazen                              3.0
# 3             Randy Pausch                              8.0
# 4                  Alhazen                              NaN
# 5          Wilder Penfield                              2.0
# 6         Claudius Ptolemy                              3.0
# 7              Jean Piaget                             10.0
# 8         Claudius Ptolemy                              3.0
# 9           Clyde Tombaugh                              2.0
# 10        Joseph Priestley                              5.0
# 11  Evangelista Torricelli                              4.0
# 12          Beatrix Potter                              6.0
# 13         Wilder Penfield                              1.0
# 14           Louis Agassiz                              6.0
# ...
